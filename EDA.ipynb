# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('bmh')

# %%
df =pd.read_csv("C:/Users/Jamuna/Desktop/DataAnalysis_Leadbook/data_analysis/data.csv")
df.head()
# Out:
#    Id                         Name    Country  Employees Ownership  \
# 0   1                Bean and Sons   Thailand        NaN   Private
# 1   2      Roberts, Smith and Cook   Thailand     2889.0   Private
# 2   3               Hubbard-Orozco   Malaysia     4373.0    Public
# 3   4     Vasquez, Stokes and Cruz   Thailand     4529.0    Public
# 4   5  Chavez, Brown and Patterson  Singapore      103.0   Private
#
#       Revenue                Industry
# 0    928502.0            Construction
# 1         NaN               Education
# 2  35471809.0  Information Technology
# 3  61934857.0               Education
# 4    672509.0              Healthcare

# %%
pwd
# Out:
# 'C:\\Users\\Jamuna'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 7 columns):
# Id           19999 non-null int64
# Name         19999 non-null object
# Country      19999 non-null object
# Employees    14991 non-null float64
# Ownership    19999 non-null object
# Revenue      14962 non-null float64
# Industry     19999 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]
del df2['Id']
print("List of dropped columns:", end=" ")
for c in df.columns:
    if c not in df2.columns:
        print(c, end=", ")
print('\n')
df = df2
# Out:
# List of dropped columns: Id,

# %%
print(df['Employees'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['Employees'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    14991.000000
# mean      3623.429991
# std       3247.800456
# min         50.000000
# 25%        374.000000
# 50%       2995.000000
# 75%       6495.000000
# max      10000.000000
# Name: Employees, dtype: float64
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-bfed48b9422a> in <module>
#       1 print(df['Employees'].describe())
#       2 plt.figure(figsize=(9, 8))
# ----> 3 sns.distplot(df['Employees'], color='g', bins=100, hist_kws={'alpha': 0.4});
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     538             raise ValueError(msg)
#     539
# --> 540         self._compute_covariance()
#     541
#     542     def _compute_covariance(self):
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     550                                                bias=False,
#     551                                                aweights=self.weights))
# --> 552             self._data_inv_cov = linalg.inv(self._data_covariance)
#     553
#     554         self.covariance = self._data_covariance * self.factor**2
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\scipy\linalg\basic.py in inv(a, overwrite_a, check_finite)
#     943
#     944     """
# --> 945     a1 = _asarray_validated(a, check_finite=check_finite)
#     946     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     947         raise ValueError('expected square matrix')
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\scipy\_lib\_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     237             raise ValueError('masked arrays are not supported')
#     238     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 239     a = toarray(a)
#     240     if not objects_ok:
#     241         if a.dtype is np.dtype('O'):
#
# c:\users\jamuna\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     459     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     460         raise ValueError(
# --> 461             "array must not contain infs or NaNs")
#     462     return a
#     463
#
# ValueError: array must not contain infs or NaNs

# %%
df2.isnull().tail()
# Out:
#         Name  Country  Employees  Ownership  Revenue  Industry
# 19994  False    False      False      False    False     False
# 19995  False    False       True      False    False     False
# 19996  False    False      False      False    False     False
# 19997  False    False      False      False    False     False
# 19998  False    False       True      False    False     False

# %%
df2.isnull().sum()
# Out:
# Name            0
# Country         0
# Employees    5008
# Ownership       0
# Revenue      5037
# Industry        0
# dtype: int64

# %%
df2[df2.Employees.isnull()]
# Out:
#                                  Name    Country  Employees Ownership  \
# 0                       Bean and Sons   Thailand        NaN   Private
# 6                         Patel Group   Hongkong        NaN    Public
# 13                       Hanson-Berry  Singapore        NaN   Private
# 15           Perez, Harrell and Smith  Singapore        NaN    Public
# 17                           Ross LLC   Hongkong        NaN    Public
# 19                        Lynn-Zuniga   Malaysia        NaN    Public
# 20         Parker, Harris and Collins   Thailand        NaN    Public
# 22                     Lopez and Sons  Singapore        NaN   Private
# 24                       Foster Group   Thailand        NaN   Private
# 28                        Lewis Group   Malaysia        NaN    Public
# 31                           Hall LLC   Malaysia        NaN   Private
# 32           Cannon, Rice and Chapman   Malaysia        NaN    Public
# 37      Hernandez, Smith and Humphrey   Hongkong        NaN    Public
# 53                        Delgado PLC   Malaysia        NaN   Private
# 56                         Taylor LLC   Thailand        NaN    Public
# 57           Leon, Ayala and Williams   Hongkong        NaN   Private
# 59                         Cruz Group   Hongkong        NaN   Private
# 60                       Wright Group  Singapore        NaN    Public
# 63                       Young-Morris   Hongkong        NaN    Public
# 64                     Flynn and Sons   Hongkong        NaN   Private
# 65                  Alvarado and Sons   Malaysia        NaN    Public
# 69                       Powell-Hines   Hongkong        NaN    Public
# 88                     Parks-Guerrero   Malaysia        NaN   Private
# 94                     Gutierrez-Ball  Singapore        NaN   Private
# 95          Mcgee, Terrell and Atkins  Singapore        NaN   Private
# 111         Smith, Brown and Robinson   Hongkong        NaN    Public
# 117                        Grant-Carr   Hongkong        NaN    Public
# 120    Sullivan, Johnson and Sullivan   Malaysia        NaN   Private
# 121             Cox, Holland and Wolf  Singapore        NaN   Private
# 123                     Roberts-Perez  Singapore        NaN   Private
# ...                               ...        ...        ...       ...
# 19871                    Schultz-Wade  Singapore        NaN    Public
# 19876                    Henry-Fisher   Hongkong        NaN   Private
# 19877                 Leblanc-Jackson   Hongkong        NaN   Private
# 19887       Martin, Miller and Walker  Singapore        NaN    Public
# 19896                     Huang Group   Malaysia        NaN    Public
# 19897                   Sanchez-Grant   Thailand        NaN    Public
# 19902                  Foster-Edwards   Malaysia        NaN   Private
# 19906      Stewart, Beltran and Moore  Singapore        NaN    Public
# 19907                    Chandler LLC   Malaysia        NaN   Private
# 19912           French, Kerr and Kirk  Singapore        NaN   Private
# 19916                     Butler-Soto   Malaysia        NaN   Private
# 19920                    Castro-Short   Hongkong        NaN    Public
# 19930                     Gomez-Baker  Singapore        NaN   Private
# 19935       Frazier, Torres and White   Malaysia        NaN   Private
# 19938                     Watkins Inc   Malaysia        NaN    Public
# 19939                     Bauer-Munoz   Thailand        NaN   Private
# 19941         Jones, Bryant and Frank  Singapore        NaN    Public
# 19943                    Walsh-George   Malaysia        NaN   Private
# 19950                   Cervantes Inc  Singapore        NaN   Private
# 19957                  Thomas-Stevens   Thailand        NaN   Private
# 19958                 Cantrell-Herman  Singapore        NaN   Private
# 19965                       Avila PLC   Thailand        NaN    Public
# 19967       Fleming, Reyes and Golden   Thailand        NaN    Public
# 19970              Dean, Ray and Rose   Hongkong        NaN   Private
# 19978                   Turner-Hayden  Singapore        NaN    Public
# 19985                  Thompson-Young   Thailand        NaN   Private
# 19988  Walton, Phillips and Velasquez   Thailand        NaN   Private
# 19990                      Hill Group   Malaysia        NaN    Public
# 19995       Gordon, Potter and Thomas  Singapore        NaN    Public
# 19998                    Kirby-Jordan   Thailand        NaN    Public
#
#         Revenue                Industry
# 0      928502.0            Construction
# 6      815807.0            Construction
# 13     754902.0  Information Technology
# 15     951283.0               Education
# 17     724186.0               Education
# 19     111024.0              Healthcare
# 20     464309.0              Healthcare
# 22     731009.0              Financials
# 24     138067.0               Education
# 28     863147.0               Education
# 31     305157.0              Financials
# 32     235404.0            Construction
# 37     761631.0              Healthcare
# 53     223859.0               Oil & Gas
# 56     747857.0               Education
# 57     309950.0               Education
# 59     152849.0            Construction
# 60     244546.0              Healthcare
# 63     460955.0            Construction
# 64     802272.0               Oil & Gas
# 65     134708.0               Education
# 69     794363.0            Construction
# 88     551902.0              Financials
# 94     898194.0               Education
# 95     754957.0               Oil & Gas
# 111    324480.0               Oil & Gas
# 117    879103.0               Oil & Gas
# 120    875189.0               Oil & Gas
# 121    587158.0            Construction
# 123    928789.0              Healthcare
# ...         ...                     ...
# 19871  268988.0              Financials
# 19876  570754.0               Education
# 19877  365909.0              Financials
# 19887  572256.0               Oil & Gas
# 19896  553237.0              Financials
# 19897  482655.0            Construction
# 19902  190738.0            Construction
# 19906  588445.0              Healthcare
# 19907  955077.0              Financials
# 19912  214274.0            Construction
# 19916  728379.0              Healthcare
# 19920  995296.0  Information Technology
# 19930  821492.0               Oil & Gas
# 19935  749184.0               Oil & Gas
# 19938  694772.0  Information Technology
# 19939  934244.0              Financials
# 19941  371841.0              Financials
# 19943  909041.0            Construction
# 19950  818278.0               Oil & Gas
# 19957  388475.0  Information Technology
# 19958  112048.0              Healthcare
# 19965  578232.0               Oil & Gas
# 19967  432358.0               Oil & Gas
# 19970  738982.0            Construction
# 19978  637125.0            Construction
# 19985  112351.0              Financials
# 19988  987666.0               Oil & Gas
# 19990  746512.0               Oil & Gas
# 19995  539051.0               Oil & Gas
# 19998  254893.0  Information Technology
#
# [5008 rows x 6 columns]

# %%
df2.shape
# Out:
# (19999, 6)

# %%
df2["Revenue"].value_counts(dropna=False)
# Out:
# NaN            5037
#  426883.0         2
#  911478.0         2
#  567856.0         2
#  178325.0         2
#  669764.0         2
#  929374.0         2
#  636470.0         2
#  957065.0         2
#  489276.0         2
#  292260.0         2
#  935564.0         2
#  222807.0         2
#  860237.0         2
#  695361.0         2
#  724667.0         2
#  938660.0         2
#  223908.0         2
#  635889.0         2
#  812008.0         2
#  579485.0         2
#  784177.0         2
#  762467.0         2
#  262825.0         2
#  121284.0         2
#  713265.0         2
#  237216.0         2
#  823340.0         2
#  683764.0         2
#  758284.0         2
#                ...
#  152870.0         1
#  21664589.0       1
#  17672336.0       1
#  64300974.0       1
#  906442.0         1
#  289380.0         1
#  644292.0         1
#  906433.0         1
#  580729.0         1
#  58011615.0       1
#  578749.0         1
#  185647.0         1
#  939195.0         1
#  27957028.0       1
#  226606.0         1
#  888931.0         1
#  677045.0         1
#  74078779.0       1
#  742578.0         1
#  709809.0         1
#  322136.0         1
#  709807.0         1
#  893173.0         1
#  69882816.0       1
#  86659737.0       1
#  387666.0         1
#  99242383.0       1
#  404049.0         1
#  18361417.0       1
#  835421.0         1
# Name: Revenue, Length: 14909, dtype: int64

# %%
df2.dropna(subset=["Employees","Revenue"],how="any").shape
# Out:
# (9954, 6)

# %%
print(df['Revenue'].describe())
plt.figure(figsize=(14, 11))
sns.distplot(df['Revenue'], color='g', bins=100, hist_kws={'alpha': 0.4});

print(df['Employees'].describe())
plt.figure(figsize=(14, 11))
sns.distplot(df['Employees'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    9.954000e+03
# mean     2.775904e+07
# std      3.289059e+07
# min      1.000100e+05
# 25%      5.497400e+05
# 50%      1.021020e+07
# 75%      5.483235e+07
# max      9.998558e+07
# Name: Revenue, dtype: float64
# count     9954.000000
# mean      2876.187965
# std       3179.504636
# min         50.000000
# 25%        274.000000
# 50%       1009.500000
# 75%       5464.000000
# max      10000.000000
# Name: Employees, dtype: float64

# %%
df2.dropna(axis=0)
# Out:
#                               Name    Country  Employees Ownership  \
# 2                   Hubbard-Orozco   Malaysia     4373.0    Public
# 3         Vasquez, Stokes and Cruz   Thailand     4529.0    Public
# 4      Chavez, Brown and Patterson  Singapore      103.0   Private
# 5                         Reed LLC   Hongkong      360.0   Private
# 9                      Brown-Perez   Thailand       72.0   Private
# 10                      Pace Group   Malaysia     8169.0    Public
# 12      Ross, Morgan and Carpenter   Thailand     4453.0    Public
# 14              Thompson-Rodriguez  Singapore      454.0   Private
# 16                     Haley Group   Malaysia      476.0   Private
# 21       Baker, Casey and Chambers  Singapore     9420.0    Public
# 23         Rogers, Chavez and Hill  Singapore     4116.0    Public
# 26                      Melton PLC   Malaysia      446.0   Private
# 33                        Moss PLC   Hongkong     9615.0    Public
# 34                   Dickson-Moore   Thailand     7164.0    Public
# 35                  Yates-Williams   Malaysia     6008.0    Public
# 38                   Ruiz and Sons   Hongkong     9225.0    Public
# 40                 Thompson-Butler   Hongkong     2703.0    Public
# 41                     Morales Inc   Thailand      385.0   Private
# 42                  Williams-Beard   Malaysia      447.0   Private
# 43                    Perez-Vaughn   Hongkong      114.0   Private
# 44                   Crawford-Webb   Thailand     9554.0    Public
# 48               Cisneros-Robinson   Hongkong      208.0   Private
# 50                       Heath Ltd  Singapore     1322.0    Public
# 51                 Bailey and Sons   Malaysia      227.0   Private
# 58                Coleman-Lawrence   Thailand      420.0   Private
# 66                       Lewis Ltd  Singapore      377.0   Private
# 67                    Baird-Garcia   Hongkong     2386.0    Public
# 70                 Carter and Sons   Hongkong      184.0   Private
# 71                    Lopez-Harris   Thailand      396.0   Private
# 72                 Lowery and Sons  Singapore      311.0   Private
# ...                            ...        ...        ...       ...
# 19945                   Kramer Inc   Hongkong     6196.0    Public
# 19946               Eaton and Sons   Thailand     6606.0    Public
# 19947              Taylor and Sons   Malaysia      460.0   Private
# 19948                 Holmes-Brown   Thailand     6109.0    Public
# 19949                Walters-Lewis   Hongkong     6278.0    Public
# 19951   Wright, Greene and Sanders   Malaysia      409.0   Private
# 19952                   Palmer Ltd   Malaysia      131.0   Private
# 19954             Mitchell-Johnson   Hongkong      466.0   Private
# 19955                Barry-Wheeler   Hongkong     3888.0    Public
# 19959    Payne, Morgan and Frazier   Hongkong      393.0   Private
# 19960              Armstrong-Boone  Singapore      129.0   Private
# 19961                      Cox Inc   Hongkong     5367.0    Public
# 19964                 Benjamin Ltd  Singapore     6536.0    Public
# 19966                Bailey-Flores   Thailand      157.0   Private
# 19968                   Ford-Roman   Hongkong     1720.0    Public
# 19969  Gomez, Bennett and Jennings   Hongkong     3836.0    Public
# 19971            Morales-Dickerson  Singapore     9495.0    Public
# 19972               Richard-Miller   Hongkong      215.0   Private
# 19973               Adams and Sons  Singapore     2390.0    Public
# 19976                    Chang Ltd   Thailand     2620.0    Public
# 19977              Madden and Sons  Singapore     4478.0    Public
# 19979    House, Robinson and Brown  Singapore      200.0   Private
# 19980              Hughes-Mccarthy  Singapore     3249.0    Public
# 19981                Martinez-Cruz   Hongkong       77.0   Private
# 19983                 Martinez LLC   Thailand     2813.0    Public
# 19989     Fisher, Madden and Adams  Singapore      391.0   Private
# 19993          Anderson-Williamson   Thailand     8985.0    Public
# 19994                    Jones LLC   Malaysia      192.0   Private
# 19996                   Cook Group  Singapore     7753.0    Public
# 19997                   Harmon LLC   Thailand     8211.0    Public
#
#           Revenue                Industry
# 2      35471809.0  Information Technology
# 3      61934857.0               Education
# 4        672509.0              Healthcare
# 5        713231.0              Healthcare
# 9        743617.0            Construction
# 10     28581159.0  Information Technology
# 12     57098691.0  Information Technology
# 14       861957.0               Education
# 16       947040.0               Oil & Gas
# 21     11767677.0            Construction
# 23     93779818.0               Education
# 26       467059.0              Healthcare
# 33     25587094.0              Healthcare
# 34     22472852.0  Information Technology
# 35     60026721.0              Healthcare
# 38     98477437.0               Oil & Gas
# 40     60807547.0              Healthcare
# 41       300140.0            Construction
# 42       838174.0              Healthcare
# 43       205620.0              Financials
# 44     13728668.0              Healthcare
# 48       606044.0              Healthcare
# 50     55528386.0  Information Technology
# 51       469015.0              Financials
# 58       428545.0               Education
# 66       369780.0            Construction
# 67     40429946.0              Healthcare
# 70       486001.0              Financials
# 71       636756.0            Construction
# 72       267175.0            Construction
# ...           ...                     ...
# 19945  23407120.0            Construction
# 19946  63696029.0  Information Technology
# 19947    961883.0              Financials
# 19948  37042191.0               Education
# 19949  89485467.0              Healthcare
# 19951    924928.0  Information Technology
# 19952    788377.0  Information Technology
# 19954    544851.0               Education
# 19955  78136428.0              Healthcare
# 19959    981758.0            Construction
# 19960    530016.0               Oil & Gas
# 19961  98634129.0               Education
# 19964  92578305.0              Healthcare
# 19966    647311.0              Financials
# 19968  82914505.0              Healthcare
# 19969  30121354.0  Information Technology
# 19971  24483980.0              Financials
# 19972    510757.0  Information Technology
# 19973  59911148.0               Education
# 19976  94264450.0              Healthcare
# 19977  71294668.0              Financials
# 19979    868351.0               Oil & Gas
# 19980  38852724.0              Healthcare
# 19981    719243.0  Information Technology
# 19983  74257015.0  Information Technology
# 19989    910565.0              Healthcare
# 19993  34428309.0               Oil & Gas
# 19994    514053.0              Healthcare
# 19996  65526276.0               Oil & Gas
# 19997  94763556.0              Financials
#
# [9954 rows x 6 columns]

# %%
cols = ['Employees', 'Revenue']
df2.dropna(subset=cols, inplace=True)
df2.shape
# Out:
# (9954, 6)
